# %% [markdown]
# # Importing liraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Loading the data

# %%
df1 = pd.read_json('Sarcasm_Headlines_Dataset.json', lines=True)
df2 = pd.read_json('Sarcasm_Headlines_Dataset_v2.json', lines=True)

# %%
df1.head(10)
# Out:
#                                         article_link  \
# 0  https://www.huffingtonpost.com/entry/versace-b...
# 1  https://www.huffingtonpost.com/entry/roseanne-...
# 2  https://local.theonion.com/mom-starting-to-fea...
# 3  https://politics.theonion.com/boehner-just-wan...
# 4  https://www.huffingtonpost.com/entry/jk-rowlin...
# 5  https://www.huffingtonpost.com/entry/advancing...
# 6  https://www.huffingtonpost.com/entry/how-meat-...
# 7  https://www.huffingtonpost.com/entry/boxed-col...
# 8  https://politics.theonion.com/top-snake-handle...
# 9  https://www.huffingtonpost.com/entry/fridays-m...
#
#                                             headline  is_sarcastic
# 0  former versace store clerk sues over secret 'b...             0
# 1  the 'roseanne' revival catches up to our thorn...             0
# 2  mom starting to fear son's web series closest ...             1
# 3  boehner just wants wife to listen, not come up...             1
# 4  j.k. rowling wishes snape happy birthday in th...             0
# 5                        advancing the world's women             0
# 6     the fascinating case for eating lab-grown meat             0
# 7  this ceo will send your kids to school, if you...             0
# 8  top snake handler leaves sinking huckabee camp...             1
# 9  friday's morning email: inside trump's presser...             0

# %%
df2.head(10)
# Out:
#    is_sarcastic                                           headline  \
# 0             1  thirtysomething scientists unveil doomsday clo...
# 1             0  dem rep. totally nails why congress is falling...
# 2             0  eat your veggies: 9 deliciously different recipes
# 3             1  inclement weather prevents liar from getting t...
# 4             1  mother comes pretty close to using word 'strea...
# 5             0                               my white inheritance
# 6             0         5 ways to file your taxes with less stress
# 7             1  richard branson's global-warming donation near...
# 8             1  shadow government getting too large to meet in...
# 9             0                 lots of parents know this scenario
#
#                                         article_link
# 0  https://www.theonion.com/thirtysomething-scien...
# 1  https://www.huffingtonpost.com/entry/donna-edw...
# 2  https://www.huffingtonpost.com/entry/eat-your-...
# 3  https://local.theonion.com/inclement-weather-p...
# 4  https://www.theonion.com/mother-comes-pretty-c...
# 5  https://www.huffingtonpost.com/entry/my-white-...
# 6  https://www.huffingtonpost.com/entry/5-ways-to...
# 7  https://www.theonion.com/richard-bransons-glob...
# 8  https://politics.theonion.com/shadow-governmen...
# 9  https://www.huffingtonpost.comhttp://pubx.co/6...

# %% [markdown]
# # Merging both the dataframe

# %%
df = df1.merge(df2)

# %%
df
# Out:
#                                             article_link  \
# 0      https://www.huffingtonpost.com/entry/versace-b...
# 1      https://www.huffingtonpost.com/entry/roseanne-...
# 2      https://local.theonion.com/mom-starting-to-fea...
# 3      https://politics.theonion.com/boehner-just-wan...
# 4      https://www.huffingtonpost.com/entry/jk-rowlin...
# ...                                                  ...
# 26707  https://www.huffingtonpost.com/entry/american-...
# 26708  https://www.huffingtonpost.com/entry/americas-...
# 26709  https://www.huffingtonpost.com/entry/reparatio...
# 26710  https://www.huffingtonpost.com/entry/israeli-b...
# 26711  https://www.huffingtonpost.com/entry/gourmet-g...
#
#                                                 headline  is_sarcastic
# 0      former versace store clerk sues over secret 'b...             0
# 1      the 'roseanne' revival catches up to our thorn...             0
# 2      mom starting to fear son's web series closest ...             1
# 3      boehner just wants wife to listen, not come up...             1
# 4      j.k. rowling wishes snape happy birthday in th...             0
# ...                                                  ...           ...
# 26707               american politics in moral free-fall             0
# 26708                            america's best 20 hikes             0
# 26709                              reparations and obama             0
# 26710  israeli ban targeting boycott supporters raise...             0
# 26711                  gourmet gifts for the foodie 2014             0
#
# [26712 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['article_link', 'headline', 'is_sarcastic'], dtype='object')

# %% [markdown]
# # Checking null values

# %%
df.isnull().sum()
# Out:
# article_link    0
# headline        0
# is_sarcastic    0
# dtype: int64

# %% [markdown]
# # Dropping article link columns

# %%
df.drop('article_link',axis=1, inplace=True)

# %%
df
# Out:
#                                                 headline  is_sarcastic
# 0      former versace store clerk sues over secret 'b...             0
# 1      the 'roseanne' revival catches up to our thorn...             0
# 2      mom starting to fear son's web series closest ...             1
# 3      boehner just wants wife to listen, not come up...             1
# 4      j.k. rowling wishes snape happy birthday in th...             0
# ...                                                  ...           ...
# 26707               american politics in moral free-fall             0
# 26708                            america's best 20 hikes             0
# 26709                              reparations and obama             0
# 26710  israeli ban targeting boycott supporters raise...             0
# 26711                  gourmet gifts for the foodie 2014             0
#
# [26712 rows x 2 columns]

# %%
df.shape
# Out:
# (26712, 2)

# %% [markdown]
# # Dropping duplicates values

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (26602, 2)

# %% [markdown]
# # Checking if html tag exist in headline column

# %%
import re
for i in df['headline'].values:
    if(len(re.findall('<.*?>', i))):
        print(i)
        break

# %% [raw]
# No html tags exist

# %%
def cleanpunc(sentence): #function to clean the word of any punctuation or special characters
    cleaned = re.sub(r'[?|!|\'|"|#]',r'',sentence)
    cleaned = re.sub(r'[.|,|)|(|\|/]',r' ',cleaned)
    return  cleaned

# %% [markdown]
# # Loading the stemmer

# %%
from nltk.stem import SnowballStemmer
sno = SnowballStemmer('english')

# %% [markdown]
# # StopWords

# %%
from nltk.corpus import stopwords
stop = set(stopwords.words('english'))

# %% [markdown]
# # Cleaning and preprocessing the data

# %%
str1 = ' '
final_string = []

for i in df['headline'].values:
    fil_word = []
    for w in i.split():
        for cleanedwords in cleanpunc(w).split():
            if((cleanedwords.isalpha()) and (len(cleanedwords) > 2)):
                if(cleanedwords.lower() not in stop):
                    s = (sno.stem((cleanedwords.lower())).encode('utf8'))
                    fil_word.append(s)
    
    str1 = b' '.join(fil_word)
    final_string.append(str1)

# %% [markdown]
# # Creating a colum in data frame of preprocessed data

# %%
df['cleanedheadline'] = final_string

# %%
df
# Out:
#                                                 headline  is_sarcastic  \
# 0      former versace store clerk sues over secret 'b...             0
# 1      the 'roseanne' revival catches up to our thorn...             0
# 2      mom starting to fear son's web series closest ...             1
# 3      boehner just wants wife to listen, not come up...             1
# 4      j.k. rowling wishes snape happy birthday in th...             0
# ...                                                  ...           ...
# 26707               american politics in moral free-fall             0
# 26708                            america's best 20 hikes             0
# 26709                              reparations and obama             0
# 26710  israeli ban targeting boycott supporters raise...             0
# 26711                  gourmet gifts for the foodie 2014             0
#
#                                          cleanedheadline
# 0      b'former versac store clerk sue secret black c...
# 1      b'roseann reviv catch thorni polit mood better...
# 2      b'mom start fear son web seri closest thing gr...
# 3           b'boehner want wife listen come altern idea'
# 4            b'rowl wish snape happi birthday magic way'
# ...                                                  ...
# 26707                            b'american polit moral'
# 26708                               b'america best hike'
# 26709                                     b'repar obama'
# 26710  b'isra ban target boycott support rais alarm a...
# 26711                              b'gourmet gift foodi'
#
# [26602 rows x 3 columns]

# %% [markdown]
# # Visulization

# %%
from wordcloud import WordCloud
pos = ' '.join(list(df[df['is_sarcastic'] == 1]['headline']))
neg = ' '.join(list(df[df['is_sarcastic'] == 0]['headline']))
pos_wc = WordCloud(width = 512, height = 512).generate(pos)
neg_wc = WordCloud(width = 512, height = 512).generate(neg)
plt.figure(figsize=(10,8))
plt.imshow(pos_wc)
plt.show()
plt.figure(figsize=(10,8))
plt.imshow(neg_wc)
plt.show()

# %% [markdown]
# # Initialiazing BOW

# %%
# df['cleanedheadline'] = df['cleanedheadline'].apply(str)


df['cleanedheadline'] = df['cleanedheadline'].apply(str)

# %%
from keras.preprocessing.text import Tokenizer
tkn = Tokenizer(nb_words=2000, filters='!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n',
                                   lower=True,split=' ')

tkn.fit_on_texts(df['cleanedheadline'].values)
from keras.preprocessing.sequence import pad_sequences


x = tkn.texts_to_sequences(df['cleanedheadline'].values)
x = pad_sequences(x)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Separating the data

# %%
y = df['is_sarcastic']
y
# Out:
# 0        0
# 1        0
# 2        1
# 3        1
# 4        0
#         ..
# 26707    0
# 26708    0
# 26709    0
# 26710    0
# 26711    0
# Name: is_sarcastic, Length: 26602, dtype: int64

# %%
from keras.utils import to_categorical
y = to_categorical(y)

# %% [markdown]
# # spliting into train and test

# %%
from sklearn.model_selection import train_test_split
x_train,x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=0)

# %%
x.shape
# Out:
# (26602, 14)

# %% [markdown]
# # Classification and prediction

# %%
from keras.models import Sequential
from keras.layers import Dense, Embedding, LSTM, SpatialDropout1D
embed_dim = 128
lstm_out = 196
max_fatures = 2000

model = Sequential()
model.add(Embedding(max_fatures, embed_dim,input_length = x.shape[1]))
model.add(SpatialDropout1D(0.4))
model.add(LSTM(lstm_out, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(2))
model.add(Dense(2,activation='softmax'))
model.compile(loss = 'categorical_crossentropy', optimizer='adam',metrics = ['accuracy'])
print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 14, 128)           256000
# _________________________________________________________________
# spatial_dropout1d_1 (Spatial (None, 14, 128)           0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 196)               254800
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 394
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 6
# =================================================================
# Total params: 511,200
# Trainable params: 511,200
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
history = model.fit(x_train,y_train,validation_split=0.2,epochs=30)
# Out:
# WARNING:tensorflow:From /home/vipin/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 17024 samples, validate on 4257 samples
# Epoch 1/30
# 17024/17024 [==============================] - 16s 964us/step - loss: 0.5658 - accuracy: 0.6947 - val_loss: 0.5128 - val_accuracy: 0.7432
# Epoch 2/30
# 17024/17024 [==============================] - 16s 938us/step - loss: 0.4633 - accuracy: 0.7737 - val_loss: 0.5046 - val_accuracy: 0.7428
# Epoch 3/30
# 17024/17024 [==============================] - 16s 935us/step - loss: 0.4315 - accuracy: 0.7918 - val_loss: 0.5187 - val_accuracy: 0.7416
# Epoch 4/30
# 17024/17024 [==============================] - 16s 943us/step - loss: 0.4083 - accuracy: 0.8032 - val_loss: 0.5205 - val_accuracy: 0.7447
# Epoch 5/30
# 17024/17024 [==============================] - 16s 938us/step - loss: 0.3895 - accuracy: 0.8134 - val_loss: 0.5502 - val_accuracy: 0.7428
# Epoch 6/30
# 17024/17024 [==============================] - 16s 942us/step - loss: 0.3699 - accuracy: 0.8252 - val_loss: 0.5812 - val_accuracy: 0.7360
# Epoch 7/30
# 17024/17024 [==============================] - 16s 954us/step - loss: 0.3542 - accuracy: 0.8322 - val_loss: 0.5798 - val_accuracy: 0.7355
# Epoch 8/30
# 17024/17024 [==============================] - 16s 965us/step - loss: 0.3367 - accuracy: 0.8412 - val_loss: 0.6217 - val_accuracy: 0.7336
# Epoch 9/30
# 17024/17024 [==============================] - 17s 1ms/step - loss: 0.3217 - accuracy: 0.8496 - val_loss: 0.6383 - val_accuracy: 0.7369
# Epoch 10/30
# 17024/17024 [==============================] - 17s 993us/step - loss: 0.3073 - accuracy: 0.8563 - val_loss: 0.6440 - val_accuracy: 0.7341
# Epoch 11/30
# 17024/17024 [==============================] - 17s 996us/step - loss: 0.2943 - accuracy: 0.8647 - val_loss: 0.7180 - val_accuracy: 0.7306
# Epoch 12/30
# 17024/17024 [==============================] - 17s 998us/step - loss: 0.2795 - accuracy: 0.8667 - val_loss: 0.7499 - val_accuracy: 0.7270
# Epoch 13/30
# 17024/17024 [==============================] - 17s 1ms/step - loss: 0.2657 - accuracy: 0.8772 - val_loss: 0.7881 - val_accuracy: 0.7235
# Epoch 14/30
# 17024/17024 [==============================] - 17s 1ms/step - loss: 0.2511 - accuracy: 0.8861 - val_loss: 0.7975 - val_accuracy: 0.7284
# Epoch 15/30
# 17024/17024 [==============================] - 18s 1ms/step - loss: 0.2364 - accuracy: 0.8914 - val_loss: 0.8841 - val_accuracy: 0.7240
# Epoch 16/30
# 17024/17024 [==============================] - 17s 1ms/step - loss: 0.2250 - accuracy: 0.8993 - val_loss: 0.9263 - val_accuracy: 0.7141
# Epoch 17/30
# 17024/17024 [==============================] - 17s 1ms/step - loss: 0.2110 - accuracy: 0.9043 - val_loss: 0.9965 - val_accuracy: 0.7275
# Epoch 18/30
# 17024/17024 [==============================] - 17s 1ms/step - loss: 0.1982 - accuracy: 0.9117 - val_loss: 1.0007 - val_accuracy: 0.7209
# Epoch 19/30
# 17024/17024 [==============================] - 18s 1ms/step - loss: 0.1914 - accuracy: 0.9136 - val_loss: 1.0470 - val_accuracy: 0.7263
# Epoch 20/30
# 17024/17024 [==============================] - 17s 1ms/step - loss: 0.1757 - accuracy: 0.9198 - val_loss: 1.2101 - val_accuracy: 0.7256
# Epoch 21/30
# 17024/17024 [==============================] - 18s 1ms/step - loss: 0.1657 - accuracy: 0.9293 - val_loss: 1.1795 - val_accuracy: 0.7263
# Epoch 22/30
# 17024/17024 [==============================] - 18s 1ms/step - loss: 0.1594 - accuracy: 0.9282 - val_loss: 1.2421 - val_accuracy: 0.7205
# Epoch 23/30
# 17024/17024 [==============================] - 17s 1ms/step - loss: 0.1562 - accuracy: 0.9317 - val_loss: 1.1861 - val_accuracy: 0.7205
# Epoch 24/30
# 17024/17024 [==============================] - 17s 1ms/step - loss: 0.1488 - accuracy: 0.9317 - val_loss: 1.2815 - val_accuracy: 0.7230
# Epoch 25/30
# 17024/17024 [==============================] - 18s 1ms/step - loss: 0.1393 - accuracy: 0.9370 - val_loss: 1.4249 - val_accuracy: 0.7228
# Epoch 26/30
# 17024/17024 [==============================] - 18s 1ms/step - loss: 0.1359 - accuracy: 0.9421 - val_loss: 1.3822 - val_accuracy: 0.7266
# Epoch 27/30
# 17024/17024 [==============================] - 18s 1ms/step - loss: 0.1327 - accuracy: 0.9406 - val_loss: 1.3629 - val_accuracy: 0.7219
# Epoch 28/30
# 17024/17024 [==============================] - 17s 1ms/step - loss: 0.1267 - accuracy: 0.9426 - val_loss: 1.4781 - val_accuracy: 0.7261
# Epoch 29/30
# 17024/17024 [==============================] - 18s 1ms/step - loss: 0.1276 - accuracy: 0.9440 - val_loss: 1.3932 - val_accuracy: 0.7202
# Epoch 30/30
# 17024/17024 [==============================] - 17s 1ms/step - loss: 0.1192 - accuracy: 0.9470 - val_loss: 1.5257 - val_accuracy: 0.7266

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
pred = model.predict(x_test)
print(classification_report(y_test, pred.round()))
print()
#print('Confusion Matrix:\n',confusion_matrix(y_test, pred))
print()
print('Accuracy : ',accuracy_score(y_test, pred.round()))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.77      0.75      2972
#            1       0.69      0.63      0.66      2349
#
#    micro avg       0.71      0.71      0.71      5321
#    macro avg       0.71      0.70      0.70      5321
# weighted avg       0.71      0.71      0.71      5321
#  samples avg       0.71      0.71      0.71      5321
#
#
#
# Accuracy :  0.7096410449163691
